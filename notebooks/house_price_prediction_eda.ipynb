# %% [markdown]
# ## House price prediction

# %%
from pandas_profiling import ProfileReport
from pathlib import Path
import numpy as np
import datetime as dt
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from scipy import stats

# %%
house_price_train_path = Path('../data/house_price_train.csv')

# %%
df_train = pd.read_csv(house_price_train_path)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Exploratory data analysis

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ### 1. Distribution

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
#df_train.profile_report()
profile = ProfileReport(df_train, minimal=True)
profile.to_notebook_iframe()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.10.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-12-15 14:09:14.079435&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ### 2. Correlation

# %%
#Analyze feature correlations
corr_df = df_train.corr()
plt.figure(figsize=(20,16))
sns.heatmap(corr_df, cmap='coolwarm');

# %%
#Analyze high correlated variables
high_corr_cols = list(corr_df.nlargest(10, 'SalePrice').index)
high_corr_df = corr_df.loc[high_corr_cols, high_corr_cols]

plt.figure(figsize=(12,6))
sns.heatmap(high_corr_df, annot=True, cmap='coolwarm');

# %%
sns.pairplot(df_train[high_corr_cols]);

# %% [markdown]
# - Highest correlation with OverallQual reflecting the overall material and finish quality (0.79)
# - Relative high correlation with GrLivArea reflecting the above ground living area in square feet (0.70)

# %%
corr['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %% [markdown]
# - We can identify several outliers that don't follow the trend looking at the plot with GrLivArea, TotalBsmtSF & 1stFirSF

# %%
#Plot highly correlated numeric features
corr_cols_num = ['GrLivArea', 'GarageArea', 'TotalBsmtSF', '1stFlrSF']

fig, axes = plt.subplots(figsize=(16,8), nrows=2, ncols=2, 
                         sharex=False, sharey=False
                        )

for col, ax in zip(corr_cols_num, axes.flatten()):
    
    sns.scatterplot(x=col, y='SalePrice', data=df_train, ax=ax)

# %%
#Plot highly correlated categorical features
corr_cols_cat = ['OverallQual', 'GarageCars']

fig, axes = plt.subplots(figsize=(20,6), nrows=1, ncols=2, 
                         sharex=False, sharey=False
                        )

for col, ax in zip(corr_cols_cat, axes.flatten()):
    
    sns.boxplot(x=col, y='SalePrice', data=df_train, ax=ax)

# %%
#Plot the effect of time on saleprice
px.scatter(df_train, 'YearBuilt', 'SalePrice')
# Out:
# <div>                            <div id="3a9c5be4-87e1-415e-a237-c0043e8e63f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a9c5be4-87e1-415e-a237-c0043e8e63f6")) {                    Plotly.newPlot(                        "3a9c5be4-87e1-415e-a237-c0043e8e63f6",                        [{"hovertemplate": "YearBuilt=%{x}<br>SalePrice=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [2003, 1976, 2001, 1915, 2000, 1993, 2004, 1973, 1931, 1939, 1965, 2005, 1962, 2006, 1960, 1929, 1970, 1967, 2004, 1958, 2005, 1930, 2002, 1976, 1968, 2007, 1951, 2007, 1957, 1927, 1920, 1966, 2007, 1959, 2005, 2004, 1994, 1954, 1953, 1955, 1965, 19
# ...

# %% [markdown]
# ### 3. Missing values

# %% [markdown]
# - PoolQC, MiscFeature, Alley, Fence, FireplaceQu and LotFrontage have more than 15% missing values which we will not impute
# - The garageX and bsmtX are already expressed in the garagecars and  variable
# - MasVnrArea and MasVnrType have a strong correlation with YearBuilt and OverallQual
# - Electrical has only one missing value so we will remove this record from the dataset

# %%
#Percentage of missing values
pd.DataFrame(df_train
              .isnull()
              .sum()
              .sort_values(ascending = False)
              .head(20)
              / len(df_train) * 100
             ,
             columns=['% of missing values']
            )
# Out:
#               % of missing values
# PoolQC                  99.520548
# MiscFeature             96.301370
# Alley                   93.767123
# Fence                   80.753425
# FireplaceQu             47.260274
# LotFrontage             17.739726
# GarageCond               5.547945
# GarageType               5.547945
# GarageYrBlt              5.547945
# GarageFinish             5.547945
# GarageQual               5.547945
# BsmtExposure             2.602740
# BsmtFinType2             2.602740
# BsmtFinType1             2.534247
# BsmtCond                 2.534247
# BsmtQual                 2.534247
# MasVnrArea               0.547945
# MasVnrType               0.547945
# Electrical               0.068493
# Utilities                0.000000

# %% [markdown]
# ### 4. Normality

# %% [markdown]
# - SalePrice is not normally distributed looking at the histplot and probability plot
# - It's skewed to the right with some long tail values

# %%
plt.figure(figsize=(12,6))
sns.histplot(df_train['SalePrice'], kde=True);

# %%
fig = plt.figure(figsize=(9,4))
ax = fig.add_axes([0,0,1,1])
stats.probplot(df_train['SalePrice'], plot=plt)
ax.get_lines()[0].set_color('tab:blue');

# %% [markdown]
# - Transforming using log helps in reaching normality

# %%
plt.figure(figsize=(12,6))
sns.histplot(np.log(df_train['SalePrice']), kde=True);

# %%
fig = plt.figure(figsize=(9,4))
ax = fig.add_axes([0,0,1,1])
stats.probplot(np.log(df_train['SalePrice']), plot=plt)
ax.get_lines()[0].set_color('tab:blue');
